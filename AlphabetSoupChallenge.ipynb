# %% [markdown]
# # Dependencies

# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# # Formulas

# %%
# Generate our categorical variable list
def cat_columns(df):
    cats = df.dtypes[df.dtypes == "object"].index.tolist()
    return cats

# Get unique values in each column with categorical values
def vcount_summary(df, cat_list):
    for i in cat_list:
        print(f'Column: {i}')
        print(f'Unique Values: {df[i].nunique()}')
        print(df[i].value_counts())
        print('-------------')
        
# Make function to bucket low values into 'other' type
def other_bucket(df, column, cutoff):
    counts = df[column].value_counts()
    replacements = list(counts[counts < cutoff].index)
    
    for i in replacements:
        df[column] = df[column].replace(i, 'Other')

# Encode categorical columns and merge with primary dataframe
def encode_merge(df, cat_list):
    for i in cat_list:
        encode_df = pd.DataFrame(enc.fit_transform(df[i].values.reshape(-1,1)))
        encode_df.columns = enc.get_feature_names([i])
        df = df.merge(encode_df,left_index=True,right_index=True).drop(i,1)
    return df

# %% [markdown]
# # Step 1: Prep Data for Model

# %%
# Read the data
charity_df = pd.read_csv("charity_data.csv")
charity_df = charity_df.drop(columns=['NAME'])
charity_df.head()
# Out:
#         EIN APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0  10520599              T10       Independent          C1000    ProductDev
# 1  10531628               T3       Independent          C2000  Preservation
# 2  10547893               T5  CompanySponsored          C3000    ProductDev
# 3  10553066               T3  CompanySponsored          C2000  Preservation
# 4  10556103               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Get a list of the columns with categorical values and show unique value counts in those columns
vcount_summary(charity_df, cat_list=cat_columns(charity_df))
# Out:
# Column: APPLICATION_TYPE
# Unique Values: 17
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64
# -------------
# Column: AFFILIATION
# Unique Values: 6
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: AFFILIATION, dtype: int64
# -------------
# Column: CLASSIFICATION
# Unique Values: 71
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1570        1
# C4500        1
# C1245        1
# C2170        1
# C4200        1
# Name: CLASSIFICATION, Length: 71, dtype: int64
# -------------
# Column: USE_CASE
# Unique Values: 5
# Preservation     28095
# ProductDev        5671
# CommunityServ      384
# Heathcare          146
# Other                3
# Name: USE_CASE, dtype: int64
# -------------
# Column: ORGANIZATION
# Unique Values: 4
# Trust           23515
# Association     10255
# Co-operative      486
# Corporation        43
# Name: ORGANIZATION, dtype: int64
# -------------
# Column: INCOME_AMT
# Unique Values: 9
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: INCOME_AMT, dtype: int64
# -------------
# Column: SPECIAL_CONSIDERATIONS
# Unique Values: 2
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64
# -------------

# %%
# Bucket low-count values into 'other' column
other_bucket(df=charity_df, column='APPLICATION_TYPE', cutoff=100)
other_bucket(df=charity_df, column='CLASSIFICATION', cutoff=100)
other_bucket(df=charity_df, column='ORGANIZATION', cutoff=1000)
other_bucket(df=charity_df, column='AFFILIATION', cutoff=100)
other_bucket(df=charity_df, column='USE_CASE', cutoff=1000)

# %%
# Check that the bucketing worked
vcount_summary(charity_df, cat_list=cat_columns(charity_df))
# Out:
# Column: APPLICATION_TYPE
# Unique Values: 10
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64
# -------------
# Column: AFFILIATION
# Unique Values: 3
# Independent         18480
# CompanySponsored    15705
# Other                 114
# Name: AFFILIATION, dtype: int64
# -------------
# Column: CLASSIFICATION
# Unique Values: 12
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64
# -------------
# Column: USE_CASE
# Unique Values: 3
# Preservation    28095
# ProductDev       5671
# Other             533
# Name: USE_CASE, dtype: int64
# -------------
# Column: ORGANIZATION
# Unique Values: 3
# Trust          23515
# Association    10255
# Other            529
# Name: ORGANIZATION, dtype: int64
# -------------
# Column: INCOME_AMT
# Unique Values: 9
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: INCOME_AMT, dtype: int64
# -------------
# Column: SPECIAL_CONSIDERATIONS
# Unique Values: 2
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64
# -------------

# %%
# Encode the bucketed columns and merge the encoded dataframes with primary dataframe
enc = OneHotEncoder(sparse=False)
charity_df = encode_merge(charity_df, cat_list=cat_columns(charity_df))

# %%
# Fit the StandardScaler
scaler = StandardScaler()

scaler.fit(charity_df)
scaled_data = scaler.transform(charity_df)

# Create a DataFrame with the scaled data
transformed_scaled_data = pd.DataFrame(scaled_data, columns=charity_df.columns)
transformed_scaled_data = transformed_scaled_data.drop(columns='IS_SUCCESSFUL')
transformed_scaled_data['IS_SUCCESSFUL'] = charity_df['IS_SUCCESSFUL']
transformed_scaled_data.head()
# Out:
#         EIN    STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0 -2.074966  0.012075 -0.031725               -0.059253              7.997514
# 1 -2.074921  0.012075 -0.030536               -0.059253             -0.125039
# 2 -2.074854  0.012075 -0.031725               -0.059253             -0.125039
# 3 -2.074833  0.012075 -0.031706               -0.059253             -0.125039
# 4 -2.074821  0.012075 -0.030146               -0.059253             -0.125039
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0             -0.179013            -1.929528            -0.216965
# 1             -0.179013             0.518261            -0.216965
# 2             -0.179013            -1.929528            -0.216965
# 3             -0.179013             0.518261            -0.216965
# 4             -0.179013             0.518261            -0.216965
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  INCOME_AMT_10000-24999  \
# 0            -0.188176            -0.191719  ...               -0.126831
# 1            -0.188176            -0.191719  ...               -0.126831
# 2             5.314171            -0.191719  ...               -0.126831
# 3            -0.188176            -0.191719  ...                7.884526
# 4            -0.188176            -0.191719  ...               -0.126831
#
#    INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                 -0.330307           -0.083944         -0.169236
# 1                 -0.330307           -0.083944         -0.169236
# 2                 -0.330307           -0.083944         -0.169236
# 3                 -0.330307           -0.083944         -0.169236
# 4                  3.027487           -0.083944         -0.169236
#
#    INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0               -0.350205        -0.063789          -0.073641
# 1               -0.350205        -0.063789          -0.073641
# 2               -0.350205        -0.063789          -0.073641
# 3               -0.350205        -0.063789          -0.073641
# 4               -0.350205        -0.063789          -0.073641
#
#    SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y  IS_SUCCESSFUL
# 0                  0.028068                 -0.028068              1
# 1                  0.028068                 -0.028068              1
# 2                  0.028068                 -0.028068              0
# 3                  0.028068                 -0.028068              1
# 4                  0.028068                 -0.028068              1
#
# [5 rows x 46 columns]

# %% [markdown]
# # Step 2: Run Models and Compare Accuracy

# %% [markdown]
# ### Attempt 1.1: Deep Neural Network (100 neurons and 6 hidden layers)

# %%
# Split our preprocessed data into our features and target arrays
y = transformed_scaled_data["IS_SUCCESSFUL"].values
X = transformed_scaled_data.drop(["IS_SUCCESSFUL","EIN"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 =  75
hidden_nodes_layer3 =  50
hidden_nodes_layer4 =  25
hidden_nodes_layer5 =  10
hidden_nodes_layer6 =  5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))
# Add hidden layers
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer6, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 100)               4500
# _________________________________________________________________
# dense_9 (Dense)              (None, 75)                7575
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                3800
# _________________________________________________________________
# dense_11 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                260
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 17,471
# Trainable params: 17,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 804/804 [==============================] - 1s 867us/step - loss: 0.5705 - accuracy: 0.7206
# Epoch 2/100
# 804/804 [==============================] - 1s 827us/step - loss: 0.5529 - accuracy: 0.7318
# Epoch 3/100
# 804/804 [==============================] - 1s 833us/step - loss: 0.5503 - accuracy: 0.7334
# Epoch 4/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5487 - accuracy: 0.7332
# Epoch 5/100
# 804/804 [==============================] - 1s 877us/step - loss: 0.5474 - accuracy: 0.7343
# Epoch 6/100
# 804/804 [==============================] - 1s 901us/step - loss: 0.5465 - accuracy: 0.7350
# Epoch 7/100
# 804/804 [==============================] - 1s 900us/step - loss: 0.5457 - accuracy: 0.7351
# Epoch 8/100
# 804/804 [==============================] - 1s 889us/step - loss: 0.5443 - accuracy: 0.7364
# Epoch 9/100
# 804/804 [==============================] - 1s 902us/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 10/100
# 804/804 [==============================] - 1s 887us/step - loss: 0.5429 - accuracy: 0.7376
# Epoch 11/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5421 - accuracy: 0.7377
# Epoch 12/100
# 804/804 [==============================] - 1s 851us/step - loss: 0.5420 - accuracy: 0.7376
# Epoch 13/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5414 - accuracy: 0.7382
# Epoch 14/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5410 - accuracy: 0.7386
# Epoch 15/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5404 - accuracy: 0.7383
# Epoch 16/100
# 804/804 [==============================] - 1s 834us/step - loss: 0.5404 - accuracy: 0.7383
# Epoch 17/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5398 - accuracy: 0.7386
# Epoch 18/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5396 - accuracy: 0.7388
# Epoch 19/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5389 - accuracy: 0.7382
# Epoch 20/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5392 - accuracy: 0.7392
# Epoch 21/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5386 - accuracy: 0.7386
# Epoch 22/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5378 - accuracy: 0.7395
# Epoch 23/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5378 - accuracy: 0.7393
# Epoch 24/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5374 - accuracy: 0.7403
# Epoch 25/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5371 - accuracy: 0.7402
# Epoch 26/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 27/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5370 - accuracy: 0.7394
# Epoch 28/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5367 - accuracy: 0.7393
# Epoch 29/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5359 - accuracy: 0.7399
# Epoch 30/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5365 - accuracy: 0.7395
# Epoch 31/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5363 - accuracy: 0.7397
# Epoch 32/100
# 804/804 [==============================] - 1s 841us/step - loss: 0.5360 - accuracy: 0.7404
# Epoch 33/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5354 - accuracy: 0.7402
# Epoch 34/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5351 - accuracy: 0.7419
# Epoch 35/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5350 - accuracy: 0.7401
# Epoch 36/100
# 804/804 [==============================] - 1s 845us/step - loss: 0.5353 - accuracy: 0.7401
# Epoch 37/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5347 - accuracy: 0.7406
# Epoch 38/100
# 804/804 [==============================] - 1s 845us/step - loss: 0.5348 - accuracy: 0.7410
# Epoch 39/100
# 804/804 [==============================] - 1s 844us/step - loss: 0.5345 - accuracy: 0.7412
# Epoch 40/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5344 - accuracy: 0.7411
# Epoch 41/100
# 804/804 [==============================] - 1s 841us/step - loss: 0.5344 - accuracy: 0.7406
# Epoch 42/100
# 804/804 [==============================] - 1s 832us/step - loss: 0.5341 - accuracy: 0.7414
# Epoch 43/100
# 804/804 [==============================] - 1s 844us/step - loss: 0.5343 - accuracy: 0.7415
# Epoch 44/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5334 - accuracy: 0.7413
# Epoch 45/100
# 804/804 [==============================] - 1s 834us/step - loss: 0.5338 - accuracy: 0.7416
# Epoch 46/100
# 804/804 [==============================] - 1s 833us/step - loss: 0.5334 - accuracy: 0.7416
# Epoch 47/100
# 804/804 [==============================] - 1s 861us/step - loss: 0.5337 - accuracy: 0.7407
# Epoch 48/100
# 804/804 [==============================] - 1s 929us/step - loss: 0.5332 - accuracy: 0.7419
# Epoch 49/100
# 804/804 [==============================] - 1s 877us/step - loss: 0.5331 - accuracy: 0.7416
# Epoch 50/100
# 804/804 [==============================] - 1s 876us/step - loss: 0.5327 - accuracy: 0.7421
# Epoch 51/100
# 804/804 [==============================] - 1s 968us/step - loss: 0.5329 - accuracy: 0.7413
# Epoch 52/100
# 804/804 [==============================] - 1s 843us/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 53/100
# 804/804 [==============================] - 1s 868us/step - loss: 0.5326 - accuracy: 0.7421
# Epoch 54/100
# 804/804 [==============================] - 1s 973us/step - loss: 0.5326 - accuracy: 0.7423
# Epoch 55/100
# 804/804 [==============================] - 1s 862us/step - loss: 0.5324 - accuracy: 0.7420
# Epoch 56/100
# 804/804 [==============================] - 1s 887us/step - loss: 0.5321 - accuracy: 0.7420
# Epoch 57/100
# 804/804 [==============================] - 1s 930us/step - loss: 0.5325 - accuracy: 0.7413
# Epoch 58/100
# 804/804 [==============================] - 1s 919us/step - loss: 0.5319 - accuracy: 0.7421
# Epoch 59/100
# 804/804 [==============================] - 1s 912us/step - loss: 0.5320 - accuracy: 0.7417
# Epoch 60/100
# 804/804 [==============================] - 1s 931us/step - loss: 0.5319 - accuracy: 0.7416
# Epoch 61/100
# 804/804 [==============================] - 1s 897us/step - loss: 0.5314 - accuracy: 0.7420
# Epoch 62/100
# 804/804 [==============================] - 1s 845us/step - loss: 0.5325 - accuracy: 0.7412
# Epoch 63/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5320 - accuracy: 0.7416
# Epoch 64/100
# 804/804 [==============================] - 1s 782us/step - loss: 0.5311 - accuracy: 0.7424
# Epoch 65/100
# 804/804 [==============================] - 1s 843us/step - loss: 0.5317 - accuracy: 0.7405
# Epoch 66/100
# 804/804 [==============================] - 1s 912us/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 67/100
# 804/804 [==============================] - 1s 802us/step - loss: 0.5313 - accuracy: 0.7420
# Epoch 68/100
# 804/804 [==============================] - 1s 799us/step - loss: 0.5318 - accuracy: 0.7414
# Epoch 69/100
# 804/804 [==============================] - 1s 819us/step - loss: 0.5321 - accuracy: 0.7424
# Epoch 70/100
# 804/804 [==============================] - 1s 780us/step - loss: 0.5312 - accuracy: 0.7421
# Epoch 71/100
# 804/804 [==============================] - 1s 803us/step - loss: 0.5311 - accuracy: 0.7422
# Epoch 72/100
# 804/804 [==============================] - 1s 794us/step - loss: 0.5316 - accuracy: 0.7412
# Epoch 73/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5310 - accuracy: 0.7418
# Epoch 74/100
# 804/804 [==============================] - 1s 808us/step - loss: 0.5309 - accuracy: 0.7417
# Epoch 75/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5320 - accuracy: 0.7402
# Epoch 76/100
# 804/804 [==============================] - 1s 799us/step - loss: 0.5307 - accuracy: 0.7422
# Epoch 77/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5307 - accuracy: 0.7422
# Epoch 78/100
# 804/804 [==============================] - 1s 814us/step - loss: 0.5310 - accuracy: 0.7419
# Epoch 79/100
# 804/804 [==============================] - 1s 854us/step - loss: 0.5314 - accuracy: 0.7420
# Epoch 80/100
# 804/804 [==============================] - 1s 727us/step - loss: 0.5315 - accuracy: 0.7418
# Epoch 81/100
# 804/804 [==============================] - 1s 774us/step - loss: 0.5309 - accuracy: 0.7417
# Epoch 82/100
# 804/804 [==============================] - 1s 907us/step - loss: 0.5304 - accuracy: 0.7418
# Epoch 83/100
# 804/804 [==============================] - 1s 781us/step - loss: 0.5313 - accuracy: 0.7408
# Epoch 84/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5302 - accuracy: 0.7426
# Epoch 85/100
# 804/804 [==============================] - 1s 806us/step - loss: 0.5304 - accuracy: 0.7421
# Epoch 86/100
# 804/804 [==============================] - 1s 958us/step - loss: 0.5311 - accuracy: 0.7410
# Epoch 87/100
# 804/804 [==============================] - 1s 874us/step - loss: 0.5302 - accuracy: 0.7417
# Epoch 88/100
# 804/804 [==============================] - 1s 782us/step - loss: 0.5299 - accuracy: 0.7422
# Epoch 89/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5297 - accuracy: 0.7425
# Epoch 90/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5301 - accuracy: 0.7424
# Epoch 91/100
# 804/804 [==============================] - 1s 802us/step - loss: 0.5302 - accuracy: 0.7422
# Epoch 92/100
# 804/804 [==============================] - 1s 845us/step - loss: 0.5297 - accuracy: 0.7419
# Epoch 93/100
# 804/804 [==============================] - 1s 924us/step - loss: 0.5308 - accuracy: 0.7421
# Epoch 94/100
# 804/804 [==============================] - 1s 879us/step - loss: 0.5300 - accuracy: 0.7422
# Epoch 95/100
# 804/804 [==============================] - 1s 819us/step - loss: 0.5297 - accuracy: 0.7420
# Epoch 96/100
# 804/804 [==============================] - 1s 806us/step - loss: 0.5297 - accuracy: 0.7425
# Epoch 97/100
# 804/804 [==============================] - 1s 917us/step - loss: 0.5295 - accuracy: 0.7428
# Epoch 98/100
# 804/804 [==============================] - 1s 867us/step - loss: 0.5299 - accuracy: 0.7423
# Epoch 99/100
# 804/804 [==============================] - 1s 794us/step - loss: 0.5303 - accuracy: 0.7423
# Epoch 100/100
# 804/804 [==============================] - 1s 918us/step - loss: 0.5305 - accuracy: 0.7424

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5624 - accuracy: 0.7255
# Loss: 0.5623919367790222, Accuracy: 0.7254810333251953

# %% [markdown]
# ### Attempt 1.2: Deep Neural Network (8 neurons and 2 hidden layers)

# %%
# Split our preprocessed data into our features and target arrays
y = transformed_scaled_data["IS_SUCCESSFUL"].values
X = transformed_scaled_data.drop(["IS_SUCCESSFUL","EIN"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 =  5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))
# Add hidden layers
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 8)                 360
# _________________________________________________________________
# dense_16 (Dense)             (None, 5)                 45
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 411
# Trainable params: 411
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#
# Epoch 90/100
# 804/804 [==============================] - 0s 475us/step - loss: 0.5426 - accuracy: 0.7375
# Epoch 91/100
# 804/804 [==============================] - 0s 474us/step - loss: 0.5425 - accuracy: 0.7372
# Epoch 92/100
# 804/804 [==============================] - 0s 486us/step - loss: 0.5423 - accuracy: 0.7373
# Epoch 93/100
# 804/804 [==============================] - 0s 478us/step - loss: 0.5424 - accuracy: 0.7372
# Epoch 94/100
# 804/804 [==============================] - 0s 464us/step - loss: 0.5425 - accuracy: 0.7371
# Epoch 95/100
# 804/804 [==============================] - 0s 473us/step - loss: 0.5421 - accuracy: 0.7370
# Epoch 96/100
# 804/804 [==============================] - 0s 472us/step - loss: 0.5426 - accuracy: 0.7369
# Epoch 97/100
# 804/804 [==============================] - 0s 497us/step - loss: 0.5423 - accuracy: 0.7379
# Epoch 98/100
# 804/804 [==============================] - 0s 472us/step - loss: 0.5425 - accuracy: 0.7372
# Epoch 99/100
# 804/804 [==============================] - 0s 487us/step - loss: 0.5423 - accuracy: 0.7372
# Epoch 100/100
# 804/804 [==============================] - 0s 487us/step - loss: 0.5421 - accuracy: 0.7368

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5519 - accuracy: 0.7257
# Loss: 0.5518501996994019, Accuracy: 0.7257142663002014

# %% [markdown]
# ### Attempt 2: SVM

# %%
# Split our preprocessed data into our features and target arrays
y = transformed_scaled_data["IS_SUCCESSFUL"].values
X = transformed_scaled_data.drop(["IS_SUCCESSFUL","EIN"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create the SVM model
svm = SVC(kernel='linear')

# Train the model
svm.fit(X_train, y_train)

# Evaluate the model
y_pred = svm.predict(X_test_scaled)
print(f" SVM model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  SVM model accuracy: 0.720

# %% [markdown]
# ### Attempt 3: Logistic Regression

# %%
# Split our preprocessed data into our features and target arrays
y = transformed_scaled_data["IS_SUCCESSFUL"].values
X = transformed_scaled_data.drop(["IS_SUCCESSFUL","EIN"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.719

# %% [markdown]
# ### Attempt 4: Random Forest

# %%
# Split our preprocessed data into our features and target arrays
y = transformed_scaled_data["IS_SUCCESSFUL"].values
X = transformed_scaled_data.drop(["IS_SUCCESSFUL","EIN"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Random forest predictive accuracy: 0.709

# %% [markdown]
# ## Highest accuracy rate reached: 72.6% (Attempt 1, deep neural network)
